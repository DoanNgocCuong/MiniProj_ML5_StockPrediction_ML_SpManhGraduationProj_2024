# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.26.4)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.7.0)
# Requirement already satisfied: absl-py in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras) (23.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->keras) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense
# from tensorflow.keras.callbacks import EarlyStopping
# from sklearn.preprocessing import MinMaxScaler
# from matplotlib.ticker import FuncFormatter

# class TimeSeriesLSTMModel:
#     def __init__(self, file_path, look_back=10):
#         """
#         Initialize the class with the file path of the dataset and look-back window.
#         """
#         self.file_path = file_path
#         self.look_back = look_back
#         self.data = None
#         self.model = None
#         self.scaler = MinMaxScaler(feature_range=(0, 1))

#     def load_and_preprocess_data(self):
#         """
#         Load the dataset and preprocess the data for LSTM.
#         """
#         # Load data
#         self.data = pd.read_csv(self.file_path)
#         self.data["close_tomor"] = self.data["close"].shift(-1)
#         self.data = self.data.iloc[:-1]
        
#         # Scaling data
#         self.data_scaled = self.scaler.fit_transform(self.data[['close_tomor']])
        
#         # Create sequences
#         X, y = [], []
#         for i in range(self.look_back, len(self.data_scaled)):
#             X.append(self.data_scaled[i - self.look_back:i, 0])  # Sequence of look_back days
#             y.append(self.data_scaled[i, 0])  # Target value

#         X, y = np.array(X), np.array(y)
#         X = X.reshape((X.shape[0], X.shape[1], 1))  # Reshape to (samples, timesteps, features)
        
#         # Split into training and testing sets
#         train_size = int(len(X) * 0.75)
#         X_train, X_test = X[:train_size], X[train_size:]
#         y_train, y_test = y[:train_size], y[train_size:]

#         return X_train, X_test, y_train, y_test

#     def build_model(self):
#         """
#         Build the LSTM model.
#         """
#         self.model = Sequential([
#             LSTM(50, activation='relu', return_sequences=True, input_shape=(self.look_back, 1)),
#             LSTM(50, activation='relu'),
#             Dense(1)
#         ])
#         self.model.compile(optimizer='adam', loss='mse')

#     def train_model(self, X_train, y_train, epochs=50, batch_size=32):
#         """
#         Train the LSTM model.
#         """
#         early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
#         self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[early_stop])

#     def evaluate_model(self, y_true, y_pred):
#         """
#         Evaluate the model performance.
#         """
#         y_true = self.scaler.inverse_transform(y_true.reshape(-1, 1))
#         y_pred = self.scaler.inverse_transform(y_pred.reshape(-1, 1))

#         print("R2:", r2_score(y_true, y_pred))
#         print("MSE:", mean_squared_error(y_true, y_pred))
#         print("RMSE:", np.sqrt(mean_squared_error(y_true, y_pred)))
#         print("MAE:", mean_absolute_error(y_true, y_pred))
#         print("MAPE%:", f"{mean_absolute_percentage_error(y_true, y_pred) * 100:.2f}%")

#     def plot_predictions(self, y_test, y_pred):
#         """
#         Plot predictions vs actual values.
#         """
#         y_test = self.scaler.inverse_transform(y_test.reshape(-1, 1))
#         y_pred = self.scaler.inverse_transform(y_pred.reshape(-1, 1))

#         plt.figure(figsize=(10, 5))
#         plt.plot(y_test, label="Actual")
#         plt.plot(y_pred, label="Predicted", linestyle="--")
#         plt.title("Test Predictions")
#         plt.xlabel("Time")
#         plt.ylabel("Value")
#         plt.legend()
#         plt.show()

#     def process(self):
#         """
#         Execute the full pipeline: load, preprocess, train, evaluate, and plot.
#         """
#         X_train, X_test, y_train, y_test = self.load_and_preprocess_data()
#         self.build_model()
#         self.train_model(X_train, y_train)
#         y_pred_train = self.model.predict(X_train)
#         y_pred_test = self.model.predict(X_test)
#         self.evaluate_model(y_test, y_pred_test)
#         self.plot_predictions(y_test, y_pred_test)

# # Example usage for one file
# file_path = "D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/FPT_stock_data.csv"
# model = TimeSeriesLSTMModel(file_path)
# model.process()
# Out:
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0331
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1043e-04
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6966e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5367e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3100e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3524e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3032e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2796e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3535e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3575e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2308e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4520e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2416e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2195e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1717e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3772e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4389e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1369e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3360e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2208e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# R2: 0.9612331992282122
# MSE: 24464669.384589877
# RMSE: 4946.177249613066
# MAE: 3823.5729840769754
# MAPE%: 3.61%

# %% [markdown]
# ## Lưu thêm kết quả vào file txt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from matplotlib.ticker import FuncFormatter


class TimeSeriesLSTMModel:
    def __init__(self, file_path, look_back=10):
        """
        Initialize the class with the file path of the dataset and look-back window.
        """
        self.file_path = file_path
        self.look_back = look_back
        self.data = None
        self.model = None
        self.scaler = MinMaxScaler(feature_range=(0, 1))

    def load_and_preprocess_data(self):
        """
        Load the dataset and preprocess the data for LSTM.
        """
        # Load data
        self.data = pd.read_csv(self.file_path)
        self.data["close_tomor"] = self.data["close"].shift(-1)
        self.data = self.data.iloc[:-1]
        
        # Scaling data
        self.data_scaled = self.scaler.fit_transform(self.data[['close_tomor']])
        
        # Create sequences
        X, y = [], []
        for i in range(self.look_back, len(self.data_scaled)):
            X.append(self.data_scaled[i - self.look_back:i, 0])  # Sequence of look_back days
            y.append(self.data_scaled[i, 0])  # Target value

        X, y = np.array(X), np.array(y)
        X = X.reshape((X.shape[0], X.shape[1], 1))  # Reshape to (samples, timesteps, features)
        
        # Split into training and testing sets
        train_size = int(len(X) * 0.75)
        X_train, X_test = X[:train_size], X[train_size:]
        y_train, y_test = y[:train_size], y[train_size:]

        return X_train, X_test, y_train, y_test

    def build_model(self):
        """
        Build the LSTM model.
        """
        self.model = Sequential([
            LSTM(50, activation='relu', return_sequences=True, input_shape=(self.look_back, 1)),
            LSTM(50, activation='relu'),
            Dense(1)
        ])
        self.model.compile(optimizer='adam', loss='mse')

    def train_model(self, X_train, y_train, epochs=50, batch_size=32):
        """
        Train the LSTM model.
        """
        early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
        self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[early_stop])

    # def evaluate_model(self, y_true, y_pred):
    #     """
    #     Evaluate the model performance.
    #     """
    #     y_true_rescaled = self.scaler.inverse_transform(y_true.reshape(-1, 1))
    #     y_pred_rescaled = self.scaler.inverse_transform(y_pred.reshape(-1, 1))

    #     # Calculate R2
    #     r2 = r2_score(y_true_rescaled, y_pred_rescaled)

    #     # Calculate Directional Accuracy
    #     da = np.mean(
    #         np.sign(y_true_rescaled[1:] - y_true_rescaled[:-1]) ==
    #         np.sign(y_pred_rescaled[1:] - y_pred_rescaled[:-1])
    #     )

    #     print("R2:", r2)
    #     print("Directional Accuracy (DA):", f"{da * 100:.2f}%")
    #     print("MSE:", mean_squared_error(y_true_rescaled, y_pred_rescaled))
    #     print("RMSE:", np.sqrt(mean_squared_error(y_true_rescaled, y_pred_rescaled)))
    #     print("MAE:", mean_absolute_error(y_true_rescaled, y_pred_rescaled))
    #     print("MAPE%:", f"{mean_absolute_percentage_error(y_true_rescaled, y_pred_rescaled) * 100:.2f}%")

    def evaluate_model(self, y_true, y_pred):
            """
            Evaluate the model performance and write results to a file.
            """
            y_true_rescaled = self.scaler.inverse_transform(y_true.reshape(-1, 1))
            y_pred_rescaled = self.scaler.inverse_transform(y_pred.reshape(-1, 1))

            # Calculate metrics
            r2 = r2_score(y_true_rescaled, y_pred_rescaled)
            da = np.mean(
                np.sign(y_true_rescaled[1:] - y_true_rescaled[:-1]) ==
                np.sign(y_pred_rescaled[1:] - y_pred_rescaled[:-1])
            )
            mse = mean_squared_error(y_true_rescaled, y_pred_rescaled)
            rmse = np.sqrt(mse)
            mae = mean_absolute_error(y_true_rescaled, y_pred_rescaled)
            mape = mean_absolute_percentage_error(y_true_rescaled, y_pred_rescaled) * 100

            # Print metrics
            print("File Path:", self.file_path)
            print("R2:", r2)
            print("Directional Accuracy (DA):", f"{da * 100:.2f}%")
            print("MSE:", mse)
            print("RMSE:", rmse)
            print("MAE:", mae)
            print("MAPE%:", f"{mape:.2f}%")

            # Write results to file
            # Tự tạo file nếu file chưa có
            # Để ghi tiếp kết quả (append) vào file mà không ghi đè, chỉ cần thay open() với chế độ "w" thành "a" (append mode).
            with open("result_LSTM_trainingModel.txt", "a") as file:
                file.write(f"File Path: {self.file_path}\n")
                file.write(f"R2: {r2:.4f}\n")
                file.write(f"Directional Accuracy (DA): {da * 100:.2f}%\n")
                file.write(f"MSE: {mse:.4f}\n")
                file.write(f"RMSE: {rmse:.4f}\n")
                file.write(f"MAE: {mae:.4f}\n")
                file.write(f"MAPE%: {mape:.2f}%\n")

            return r2, da


    def plot_predictions(self, y_test, y_pred, num_samples=50):
        """
        Plot predictions vs actual values with both scatter and line plots.
        """
        y_test_rescaled = self.scaler.inverse_transform(y_test.reshape(-1, 1))
        y_pred_rescaled = self.scaler.inverse_transform(y_pred.reshape(-1, 1))

        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

        # Scatter plot
        ax1.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.5)
        ax1.set_title("Predictions vs Actual")
        ax1.set_xlabel("Actual Values")
        ax1.set_ylabel("Predicted Values")

        # Add y=x line
        min_val = min(y_test_rescaled.min(), y_pred_rescaled.min())
        max_val = max(y_test_rescaled.max(), y_pred_rescaled.max())
        ax1.plot([min_val, max_val], [min_val, max_val], 'r--')

        # Line plot
        x_points = range(num_samples)
        ax2.plot(x_points, y_test_rescaled[:num_samples], 'b-', label='Actual')
        ax2.plot(x_points, y_pred_rescaled[:num_samples], 'orange', linestyle='--', label='Predicted')
        
        ax2.set_title("Test Predictions")
        ax2.set_xlabel("Point")
        ax2.set_ylabel("Value")
        ax2.legend()

        plt.tight_layout()
        plt.show()

    def process(self):
        """
        Execute the full pipeline: load, preprocess, train, evaluate, and plot.
        """
        X_train, X_test, y_train, y_test = self.load_and_preprocess_data()
        self.build_model()
        self.train_model(X_train, y_train)
        y_pred_train = self.model.predict(X_train)
        y_pred_test = self.model.predict(X_test)
        self.evaluate_model(y_test, y_pred_test)
        self.plot_predictions(y_test, y_pred_test)

# Example usage for one file
file_path = "D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/FPT_stock_data.csv"
model = TimeSeriesLSTMModel(file_path)
model.process()
# Out:
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0337
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9617e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6209e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4421e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5303e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5496e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4559e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4714e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8048e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5108e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4075e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4854e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3840e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4441e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3237e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3755e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5500e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5844e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1511e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5278e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2725e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4688e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6382e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1741e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4123e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2662e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3247e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2794e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4794e-04
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3439e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3189e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/FPT_stock_data.csv
# R2: 0.9729330670405993
# Directional Accuracy (DA): 46.72%
# MSE: 17081202.289679088
# RMSE: 4132.941118583603
# MAE: 3261.23290616485
# MAPE%: 3.21%

# %%
import os

# Đường dẫn tới thư mục chứa các file CSV
folder_path = "D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/"

# Lấy danh sách tất cả các file CSV trong thư mục
file_paths = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".csv")]

# Chạy model process cho từng file
for file_path in file_paths:
    print(f"Processing file: {file_path}")
    print()
    model = TimeSeriesLSTMModel(file_path)
    model.process()
    print("="*50)  # Ngăn cách giữa các file
# Out:
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/CMG_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0362
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2897e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3066e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4139e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3565e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8714e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3964e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0991e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9365e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2772e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3965e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9572e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6444e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1335e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6626e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9831e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3067e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3805e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3177e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0439e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4958e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1398e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8164e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1287e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7829e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3984e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9029e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7858e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1207e-04
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4907e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0744e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3913e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5692e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3555e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4827e-04
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2559e-04
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1925e-04
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9595e-04
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4529e-04
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3230e-04
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2621e-04
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3221e-04
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9008e-04
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9409e-04
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9007e-04
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1112e-04
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0188e-04
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8128e-04
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2030e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/CMG_stock_data.csv
# R2: 0.7986278959615508
# Directional Accuracy (DA): 47.54%
# MSE: 18124839.420270666
# RMSE: 4257.327732307047
# MAE: 2637.834415446185
# MAPE%: 4.86%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/CMT_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0423
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0013
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2093e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.2950e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.3538e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.1896e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.6928e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8996e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.7299e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.1437e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.7921e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.4619e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.5700e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.0868e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.5780e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8806e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3782e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0322e-04
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.9074e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1200e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.7618e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7852e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6023e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0011
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9463e-04
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.7870e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/CMT_stock_data.csv
# R2: 0.9051048111805544
# Directional Accuracy (DA): 38.36%
# MSE: 1679012.4013318466
# RMSE: 1295.7671092182602
# MAE: 831.1867235527664
# MAPE%: 4.93%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/DGW_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.1278
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0035
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0017
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0015
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0013
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.7835e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.7797e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.5150e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9444e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6322e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.3666e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4609e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1303e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.5214e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9426e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.2695e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.2669e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.3131e-04
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.8256e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3832e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3746e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1283e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0147e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.3798e-04
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.8683e-04
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2990e-04
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5258e-04
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.5050e-04
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.8440e-04
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9863e-04
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6312e-04
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.3859e-04
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6991e-04
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.3338e-04
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.0085e-04
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3921e-04
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.1911e-04
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.4990e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/DGW_stock_data.csv
# R2: 0.8331899436440757
# Directional Accuracy (DA): 43.44%
# MSE: 3535503.8598313085
# RMSE: 1880.2935568233245
# MAE: 1524.3670278440054
# MAPE%: 3.59%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/ELC_stock_data.csv
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.0389
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.2528e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7652e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.7821e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3804e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1969e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7253e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.9427e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8389e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0838e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6080e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1961e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6767e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7503e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5123e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9435e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.9237e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1053e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4757e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4899e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.3257e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7192e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1455e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6456e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6894e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0193e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/ELC_stock_data.csv
# R2: 0.9259390445559657
# Directional Accuracy (DA): 46.45%
# MSE: 1800665.328690945
# RMSE: 1341.8887169549287
# MAE: 1094.5692507876363
# MAPE%: 5.16%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/FPT_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - loss: 0.0378
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8960e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5315e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4973e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3544e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6836e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2519e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3043e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2906e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2626e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3660e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2770e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1233e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1249e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2046e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2363e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5592e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4478e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1623e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3355e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1275e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0119e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1558e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2137e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4276e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2193e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/FPT_stock_data.csv
# R2: 0.959609065738093
# Directional Accuracy (DA): 45.08%
# MSE: 25489615.680935312
# RMSE: 5048.724163680891
# MAE: 4026.8258685286105
# MAPE%: 3.94%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/SAM_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0348
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0018
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0019
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0011
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0013
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0013
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0011
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.0986e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.3618e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0017
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2299e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5405e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.7650e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.6978e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.1492e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 7.3447e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.6107e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.4848e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.9704e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.5830e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0010
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6869e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.0822e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0825e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3416e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2752e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.4676e-04
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.5818e-04
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.1022e-04
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4403e-04
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4677e-04
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3356e-04
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.5688e-04
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3510e-04
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4086e-04
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5665e-04
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9106e-04
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8459e-04
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0757e-04
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7984e-04
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4500e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/SAM_stock_data.csv
# R2: 0.8526516399180402
# Directional Accuracy (DA): 45.08%
# MSE: 34768.13389814583
# RMSE: 186.46215138238063
# MAE: 132.58548114994895
# MAPE%: 1.93%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VGC_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0703
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5104e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4266e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4571e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1951e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8013e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6447e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1257e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3398e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8838e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1774e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7911e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7174e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5257e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0687e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8087e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2562e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2275e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5796e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8624e-04
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3386e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VGC_stock_data.csv
# R2: 0.9281639828295746
# Directional Accuracy (DA): 44.51%
# MSE: 1802652.9990219325
# RMSE: 1342.6291368140096
# MAE: 1011.7061001712328
# MAPE%: 2.16%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VGI_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0118
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2128e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6603e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1729e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4216e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4006e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4512e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4263e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4683e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2172e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7676e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2403e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8594e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9706e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8298e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9999e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7977e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8546e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4982e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2392e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5290e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4491e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4481e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3894e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3496e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0546e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5863e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8700e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2139e-04
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9941e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2813e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3102e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8314e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9911e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4291e-04
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0567e-04
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9386e-04
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9045e-04
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7335e-04
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8078e-04
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9661e-04
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0936e-04
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0380e-04
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8039e-04
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9628e-04
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7538e-04
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7767e-04
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7983e-04
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8025e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VGI_stock_data.csv
# R2: 0.92700187303362
# Directional Accuracy (DA): 49.45%
# MSE: 52926661.807576016
# RMSE: 7275.071257903665
# MAE: 4132.262761835831
# MAPE%: 6.04%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VTL_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1177
# Epoch 2/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0069
# Epoch 3/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0042
# Epoch 4/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036
# Epoch 5/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040
# Epoch 6/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 7/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 8/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 9/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 10/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 11/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 12/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 13/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 14/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 15/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 16/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 17/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014
# Epoch 18/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Epoch 19/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013
# Epoch 20/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 21/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 22/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012
# Epoch 23/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011
# Epoch 24/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 25/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 26/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 27/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 28/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 29/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 30/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7342e-04
# Epoch 31/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 32/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5574e-04
# Epoch 33/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2896e-04
# Epoch 34/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 35/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010
# Epoch 36/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4727e-04
# Epoch 37/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5778e-04
# Epoch 38/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 39/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2946e-04
# Epoch 40/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9294e-04
# Epoch 41/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9928e-04
# Epoch 42/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2328e-04
# Epoch 43/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7831e-04
# Epoch 44/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6373e-04
# Epoch 45/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2750e-04
# Epoch 46/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8530e-04
# Epoch 47/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7521e-04
# Epoch 48/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6144e-04
# Epoch 49/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2899e-04
# Epoch 50/50
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5754e-04
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VTL_stock_data.csv
# R2: 0.9498710644301699
# Directional Accuracy (DA): 62.36%
# MSE: 675797.0944866786
# RMSE: 822.0687893885029
# MAE: 472.04129963959525
# MAPE%: 6.70%
# ==================================================
# Processing file: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VTP_stock_data.csv
#
# Epoch 1/50
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0825
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1092e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1133e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3464e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6018e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3605e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9760e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3885e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4924e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2022e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9355e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3551e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4671e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5511e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7562e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3228e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4592e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8098e-04
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3235e-04
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3306e-04
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1336e-04
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6807e-04
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2498e-04
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0774e-04
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7984e-04
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2529e-04
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7881e-04
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8496e-04
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1460e-04
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1734e-04
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4383e-04
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6465e-04
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4139e-04
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3651e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1027e-04
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3505e-04
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7625e-04
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1486e-04
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9630e-04
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1250e-04
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2724e-04
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9123e-04
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1814e-04
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9652e-04
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1222e-04
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3609e-04
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4419e-04
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8699e-04
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7646e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# File Path: D:/OneDrive - Hanoi University of Science and Technology/GIT/MiniProj_StockPrediction_ML_SpManhGraduationProj_2024/data/raw20192024/VTP_stock_data.csv
# R2: 0.9780525018690114
# Directional Accuracy (DA): 48.90%
# MSE: 9858247.20939595
# RMSE: 3139.784580093983
# MAE: 2078.7054687500004
# MAPE%: 3.04%
# ==================================================
